# %%
import sys, pandas as pd, numpy as np, matplotlib.pyplot as plt
print(sys.executable)  # どのPythonか確認（/usr/local/bin/python が出ればOK）
pd.DataFrame({"x":[1,2,3], "y":[1,4,9]}).plot(x="x", y="y")
plt.show()
# Out:
# /usr/local/bin/python
